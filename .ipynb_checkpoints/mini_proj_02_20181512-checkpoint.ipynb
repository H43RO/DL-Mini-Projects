# %%
import sys
assert sys.version_info >= (3, 5)

# Is this notebook running on Colab or Kaggle?
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "cnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
def plot_image(image):
    plt.imshow(image, cmap="gray", interpolation="nearest")
    plt.axis("off")

def plot_color_image(image):
    plt.imshow(image, interpolation="nearest")
    plt.axis("off")

# %%
import pandas as pd
ADL_DATA_PATH = "./datasets/train.csv"

def load_ADL_data(adl_path=ADL_DATA_PATH):
    return pd.read_csv(adl_path)

adl = load_ADL_data()
adl.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
adl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
adl.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      7352.000000                      7352.000000
# mean                         -0.307009                        -0.625294
# std                           0.321011                         0.307584
# min                          -0.995357                        -0.999765
# 25%                          -0.542602                        -0.845573
# 50%                          -0.343685                        -0.711692
# 75%                          -0.126979                        -0.503878
# max                           0.989538                         0.956845
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  7352.000000                           7352.000000
# mean                      0.008684                              0.002186
# std                       0.336787                              0.448306
# min                      -0.976580                             -1.000000
# 25%                      -0.121527                             -0.289549
# 50%                       0.009509                              0.008943
# 75%                       0.150865                              0.292861
# max                       1.000000                              1.000000
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       7352.000000                           7352.000000
# mean                           0.008726                             -0.005981
# std                            0.608303                              0.477975
# min                           -1.000000                             -1.000000
# 25%                           -0.482273                             -0.376341
# 50%                            0.008735                             -0.000368
# 75%                            0.506187                              0.359368
# max                            0.998702                              0.996078
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           7352.000000           7352.000000           7352.000000
# mean              -0.489547              0.058593             -0.056515
# std                0.511807              0.297480              0.279122
# min               -1.000000             -1.000000             -1.000000
# 25%               -0.812065             -0.017885             -0.143414
# 50%               -0.709417              0.182071              0.003181
# 75%               -0.509079              0.248353              0.107659
# max                1.000000              0.478157              1.000000
#
#            subject
# count  7352.000000
# mean     17.413085
# std       8.975143
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %%
adl_activity = adl[["Activity"]]
adl_activity.head()
# Out:
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING

# %%
y_train = adl['Activity'].copy()
X_train = adl.drop('Activity', axis=1).copy()

# %%
num_classes = 6

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

label_encoder = LabelEncoder()
label_encoder.fit(y_train)

y_train = label_encoder.transform(y_train)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)

# %%
def build_model():
    inputs = tf.keras.Input(shape=(X_train.shape[1],))
    x = tf.keras.layers.Dense(64, activation='relu')(inputs)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    x = tf.keras.layers.Dense(64, activation='selu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

model = build_model()

# %%
model.summary()
# Out:
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        [(None, 562)]             0
# _________________________________________________________________
# dense_83 (Dense)             (None, 64)                36032
# _________________________________________________________________
# dense_84 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_85 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_86 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 44,742
# Trainable params: 44,742
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32
epochs = 25


history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint('./model.h5', save_best_only=True),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.1,
            patience=1
        )
    ]
)
# Out:
# Train on 5881 samples, validate on 1471 samples
# Epoch 1/25
# 5881/5881 [==============================] - 2s 339us/sample - loss: 0.5889 - accuracy: 0.7745 - val_loss: 0.2581 - val_accuracy: 0.9041
# Epoch 2/25
# 5881/5881 [==============================] - 1s 171us/sample - loss: 0.2066 - accuracy: 0.9218 - val_loss: 0.1791 - val_accuracy: 0.9313
# Epoch 3/25
# 5881/5881 [==============================] - 1s 172us/sample - loss: 0.1476 - accuracy: 0.9424 - val_loss: 0.1360 - val_accuracy: 0.9449
# Epoch 4/25
# 5881/5881 [==============================] - 1s 167us/sample - loss: 0.1359 - accuracy: 0.9456 - val_loss: 0.2014 - val_accuracy: 0.9137
# Epoch 5/25
# 5881/5881 [==============================] - 1s 168us/sample - loss: 0.0753 - accuracy: 0.9757 - val_loss: 0.1335 - val_accuracy: 0.9429
# Epoch 6/25
# 5881/5881 [==============================] - 1s 171us/sample - loss: 0.0688 - accuracy: 0.9772 - val_loss: 0.1305 - val_accuracy: 0.9443
# Epoch 7/25
# 5881/5881 [==============================] - 1s 172us/sample - loss: 0.0656 - accuracy: 0.9781 - val_loss: 0.1292 - val_accuracy: 0.9443
# Epoch 8/25
# 5881/5881 [==============================] - 1s 170us/sample - loss: 0.0640 - accuracy: 0.9774 - val_loss: 0.1251 - val_accuracy: 0.9449
# Epoch 9/25
# 5881/5881 [==============================] - 1s 167us/sample - loss: 0.0627 - accuracy: 0.9789 - val_loss: 0.1197 - val_accuracy: 0.9477
# Epoch 10/25
# 5881/5881 [==============================] - 1s 163us/sample - loss: 0.0597 - accuracy: 0.9794 - val_loss: 0.1386 - val_accuracy: 0.9477
# Epoch 11/25
# 5881/5881 [==============================] - 1s 163us/sample - loss: 0.0568 - accuracy: 0.9808 - val_loss: 0.1225 - val_accuracy: 0.9477
# Epoch 12/25
# 5881/5881 [==============================] - 1s 165us/sample - loss: 0.0560 - accuracy: 0.9816 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 13/25
# 5881/5881 [==============================] - 1s 168us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 14/25
# 5881/5881 [==============================] - 1s 169us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 15/25
# 5881/5881 [==============================] - 1s 167us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 16/25
# 5881/5881 [==============================] - 1s 164us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 17/25
# 5881/5881 [==============================] - 1s 165us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 18/25
# 5881/5881 [==============================] - 1s 164us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 19/25
# 5881/5881 [==============================] - 1s 168us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 20/25
# 5881/5881 [==============================] - 1s 169us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 21/25
# 5881/5881 [==============================] - 1s 166us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 22/25
# 5881/5881 [==============================] - 1s 168us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 23/25
# 5881/5881 [==============================] - 1s 171us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 24/25
# 5881/5881 [==============================] - 1s 167us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477
# Epoch 25/25
# 5881/5881 [==============================] - 1s 168us/sample - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9477

# %%
plt.figure(figsize=(16, 10))

epochs_range = range(epochs)
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(
    epochs_range,
    train_loss,
    label="Training Loss"
)

plt.plot(
    epochs_range,
    val_loss,
    label="Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend()
plt.title("Loss Over Time")

plt.show()

# %%
import numpy as np

k = 10
num_val_samples = len(X_train) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print('processing fold #', i)
    # Prepare the validation data: data from partition # k
    val_data = X_train[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = y_train[i * num_val_samples: (i + 1) * num_val_samples]

    # Prepare the training data: data from all other partitions
    partial_train_data = np.concatenate(
        [X_train[:i * num_val_samples],
         X_train[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [y_train[:i * num_val_samples],
         y_train[(i + 1) * num_val_samples:]],
        axis=0)

    model = build_model()
    # Train the model (in silent mode, verbose=0)
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, verbose=0)
    # Evaluate the model on the validation data
    loss, acc = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(acc)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3
# processing fold # 4
# processing fold # 5
# processing fold # 6
# processing fold # 7
# processing fold # 8
# processing fold # 9

# %%
all_scores
# Out:
# [0.97959185,
#  0.862585,
#  0.9360544,
#  0.8612245,
#  0.8829932,
#  0.9455782,
#  0.9659864,
#  0.9442177,
#  0.95782316,
#  0.9727891]

# %%
np.mean(all_scores)
# Out:
# 0.93088424
